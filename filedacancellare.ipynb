# %%
import numpy as np
import hsim.core.pymulate as pym
from pymoo.core.problem import ElementwiseProblem
from pymoo.algorithms.soo.nonconvex.ga import GA
from pymoo.optimize import minimize
from pymoo.operators.sampling.rnd import PermutationRandomSampling
from pymoo.operators.crossover.ox import OrderCrossover
from pymoo.operators.mutation.inversion import InversionMutation
from pymoo.termination.default import DefaultSingleObjectiveTermination
import time
import copy
import lavoro as lav

class Problem(ElementwiseProblem):
    def __init__(self):
        self.lab = lav.Lab()
        super().__init__(n_var=10, n_obj=1)
    
    def _evaluate(self, x, out, *args, **kwargs):
        lista = lav.batchCreate(1, numJobs=10)
        sorted_lista = [lista[i] for i in x]
        self.lab.gate.Store.items = copy.copy(sorted_lista)
        self.lab.run(1111)
        df = self.lab.env.state_log
        Cmax = self.lab.calculate_makespan(df)
        out["F"] = Cmax

problem = Problem()

algorithm = GA(
    pop_size=20,
    sampling=PermutationRandomSampling(),
    mutation=InversionMutation(),
    crossover=OrderCrossover(),
    eliminate_duplicates=True
)

res = minimize(problem, algorithm, seed=1, verbose=False)

print(f"Best solution found: {res.X}")
print(f"Function value: {res.F}")
# Out:
# c:\Users\Utente\GitHub\hsim\hsim\core\core.py:57: UserWarning: Bypassing "None" callbakcs
#   warn('Bypassing "None" callbakcs')
# Time 1111 <= 1111 (current time) --> executing until 2222
# Time 1111 <= 2222 (current time) --> executing until 3333
# Time 1111 <= 3333 (current time) --> executing until 4444
# Time 1111 <= 4444 (current time) --> executing until 5555
# Time 1111 <= 5555 (current time) --> executing until 6666
# Time 1111 <= 6666 (current time) --> executing until 7777
# Time 1111 <= 7777 (current time) --> executing until 8888
# Time 1111 <= 8888 (current time) --> executing until 9999
# Time 1111 <= 9999 (current time) --> executing until 11110
# Time 1111 <= 11110 (current time) --> executing until 12221
# Time 1111 <= 12221 (current time) --> executing until 13332
# Time 1111 <= 13332 (current time) --> executing until 14443
# Time 1111 <= 14443 (current time) --> executing until 15554
# Time 1111 <= 15554 (current time) --> executing until 16665
# Time 1111 <= 16665 (current time) --> executing until 17776
# Time 1111 <= 17776 (current time) --> executing until 18887
# Time 1111 <= 18887 (current time) --> executing until 19998
# Time 1111 <= 19998 (current time) --> executing until 21109
# Time 1111 <= 21109 (current time) --> executing until 22220
# Time 1111 <= 22220 (current time) --> executing until 23331
# Time 1111 <= 23331 (current time) --> executing until 24442
# Time 1111 <= 24442 (current time) --> executing until 25553
# Time 1111 <= 25553 (current time) --> executing until 26664
# Time 1111 <= 26664 (current time) --> executing until 27775
# Time 1111 <= 27775 (current time) --> executing until 28886
# Time 1111 <= 28886 (current time) --> executing until 29997
# Time 1111 <= 29997 (current time) --> executing until 31108
# Time 1111 <= 31108 (current time) --> executing until 32219
# Time 1111 <= 32219 (current time) --> executing until 33330
# Time 1111 <= 33330 (current time) --> executing until 34441
# Time 1111 <= 34441 (current time) --> executing until 35552
# Time 1111 <= 35552 (current time) --> executing until 36663
# Time 1111 <= 36663 (current time) --> executing until 37774
# Time 1111 <= 37774 (current time) --> executing until 38885
# Time 1111 <= 38885 (current time) --> executing until 39996
# Time 1111 <= 39996 (current time) --> executing until 41107
# Time 1111 <= 41107 (current time) --> executing until 42218
# Time 1111 <= 42218 (current time) --> executing until 43329
# Time 1111 <= 43329 (current time) --> executing until 44440
# Time 1111 <= 44440 (current time) --> executing until 45551
# Time 1111 <= 45551 (current time) --> executing until 46662
# Time 1111 <= 46662 (current time) --> executing until 47773
# Time 1111 <= 47773 (current time) --> executing until 48884
# Time 1111 <= 48884 (current time) --> executing until 49995
# Time 1111 <= 49995 (current time) --> executing until 51106
# Time 1111 <= 51106 (current time) --> executing until 52217
# Time 1111 <= 52217 (current time) --> executing until 53328
# Time 1111 <= 53328 (current time) --> executing until 54439
# Time 1111 <= 54439 (current time) --> executing until 55550
# Time 1111 <= 55550 (current time) --> executing until 56661
# Time 1111 <= 56661 (current time) --> executing until 57772
# Time 1111 <= 57772 (current time) --> executing until 58883
# Time 1111 <= 58883 (current time) --> executing until 59994
# Time 1111 <= 59994 (current time) --> executing until 61105
# Time 1111 <= 61105 (current time) --> executing until 62216
# Time 1111 <= 62216 (current time) --> executing until 63327
# Time 1111 <= 63327 (current time) --> executing until 64438
# Time 1111 <= 64438 (current time) --> executing until 65549
# Time 1111 <= 65549 (current time) --> executing until 66660
# Time 1111 <= 66660 (current time) --> executing until 67771
# Time 1111 <= 67771 (current time) --> executing until 68882
# Time 1111 <= 68882 (current time) --> executing until 69993
# Time 1111 <= 69993 (current time) --> executing until 71104
# Time 1111 <= 71104 (current time) --> executing until 72215
# Time 1111 <= 72215 (current time) --> executing until 73326
# Time 1111 <= 73326 (current time) --> executing until 74437
# Time 1111 <= 74437 (current time) --> executing until 75548
# Time 1111 <= 75548 (current time) --> executing until 76659
# Time 1111 <= 76659 (current time) --> executing until 77770
# Time 1111 <= 77770 (current time) --> executing until 78881
# Time 1111 <= 78881 (current time) --> executing until 79992
# Time 1111 <= 79992 (current time) --> executing until 81103
# Time 1111 <= 81103 (current time) --> executing until 82214
# Time 1111 <= 82214 (current time) --> executing until 83325
# Time 1111 <= 83325 (current time) --> executing until 84436
# Time 1111 <= 84436 (current time) --> executing until 85547
# Time 1111 <= 85547 (current time) --> executing until 86658
# Time 1111 <= 86658 (current time) --> executing until 87769
# Time 1111 <= 87769 (current time) --> executing until 88880
# Time 1111 <= 88880 (current time) --> executing until 89991
# Time 1111 <= 89991 (current time) --> executing until 91102
# Time 1111 <= 91102 (current time) --> executing until 92213
# Time 1111 <= 92213 (current time) --> executing until 93324
# Time 1111 <= 93324 (current time) --> executing until 94435
# Time 1111 <= 94435 (current time) --> executing until 95546
# Time 1111 <= 95546 (current time) --> executing until 96657
# Time 1111 <= 96657 (current time) --> executing until 97768
# Time 1111 <= 97768 (current time) --> executing until 98879
# Time 1111 <= 98879 (current time) --> executing until 99990
# Time 1111 <= 99990 (current time) --> executing until 101101
# Time 1111 <= 101101 (current time) --> executing until 102212
# Time 1111 <= 102212 (current time) --> executing until 103323
# Time 1111 <= 103323 (current time) --> executing until 104434
# Time 1111 <= 104434 (current time) --> executing until 105545
# Time 1111 <= 105545 (current time) --> executing until 106656
# Time 1111 <= 106656 (current time) --> executing until 107767
# Time 1111 <= 107767 (current time) --> executing until 108878
# Time 1111 <= 108878 (current time) --> executing until 109989
# Time 1111 <= 109989 (current time) --> executing until 111100
# Time 1111 <= 111100 (current time) --> executing until 112211
# Time 1111 <= 112211 (current time) --> executing until 113322
# Time 1111 <= 113322 (current time) --> executing until 114433
# Time 1111 <= 114433 (current time) --> executing until 115544
# Time 1111 <= 115544 (current time) --> executing until 116655
# Time 1111 <= 116655 (current time) --> executing until 117766
# Time 1111 <= 117766 (current time) --> executing until 118877
# Time 1111 <= 118877 (current time) --> executing until 119988
# Time 1111 <= 119988 (current time) --> executing until 121099
# Time 1111 <= 121099 (current time) --> executing until 122210
# Time 1111 <= 122210 (current time) --> executing until 123321
# Time 1111 <= 123321 (current time) --> executing until 124432
# Time 1111 <= 124432 (current time) --> executing until 125543
# Time 1111 <= 125543 (current time) --> executing until 126654
# Time 1111 <= 126654 (current time) --> executing until 127765
# Time 1111 <= 127765 (current time) --> executing until 128876
# Time 1111 <= 128876 (current time) --> executing until 129987
# Time 1111 <= 129987 (current time) --> executing until 131098
# Time 1111 <= 131098 (current time) --> executing until 132209
# Time 1111 <= 132209 (current time) --> executing until 133320
# Time 1111 <= 133320 (current time) --> executing until 134431
# Time 1111 <= 134431 (current time) --> executing until 135542
# Time 1111 <= 135542 (current time) --> executing until 136653
# Time 1111 <= 136653 (current time) --> executing until 137764
# Time 1111 <= 137764 (current time) --> executing until 138875
# Time 1111 <= 138875 (current time) --> executing until 139986
# Time 1111 <= 139986 (current time) --> executing until 141097
# Time 1111 <= 141097 (current time) --> executing until 142208
# Time 1111 <= 142208 (current time) --> executing until 143319
# Time 1111 <= 143319 (current time) --> executing until 144430
# Time 1111 <= 144430 (current time) --> executing until 145541
# Time 1111 <= 145541 (current time) --> executing until 146652
# Time 1111 <= 146652 (current time) --> executing until 147763
# Time 1111 <= 147763 (current time) --> executing until 148874
# Time 1111 <= 148874 (current time) --> executing until 149985
# Time 1111 <= 149985 (current time) --> executing until 151096
# Time 1111 <= 151096 (current time) --> executing until 152207
# Time 1111 <= 152207 (current time) --> executing until 153318
# Time 1111 <= 153318 (current time) --> executing until 154429
# Time 1111 <= 154429 (current time) --> executing until 155540
# Time 1111 <= 155540 (current time) --> executing until 156651
# Time 1111 <= 156651 (current time) --> executing until 157762
# Time 1111 <= 157762 (current time) --> executing until 158873
# Time 1111 <= 158873 (current time) --> executing until 159984
# Time 1111 <= 159984 (current time) --> executing until 161095
# Time 1111 <= 161095 (current time) --> executing until 162206
# Time 1111 <= 162206 (current time) --> executing until 163317
# Time 1111 <= 163317 (current time) --> executing until 164428
# Time 1111 <= 164428 (current time) --> executing until 165539
# Time 1111 <= 165539 (current time) --> executing until 166650
# Time 1111 <= 166650 (current time) --> executing until 167761
# Time 1111 <= 167761 (current time) --> executing until 168872
# Time 1111 <= 168872 (current time) --> executing until 169983
# Time 1111 <= 169983 (current time) --> executing until 171094
# Time 1111 <= 171094 (current time) --> executing until 172205
# Time 1111 <= 172205 (current time) --> executing until 173316
# Time 1111 <= 173316 (current time) --> executing until 174427
# Time 1111 <= 174427 (current time) --> executing until 175538
# Time 1111 <= 175538 (current time) --> executing until 176649
# Time 1111 <= 176649 (current time) --> executing until 177760
# Time 1111 <= 177760 (current time) --> executing until 178871
# Time 1111 <= 178871 (current time) --> executing until 179982
# Time 1111 <= 179982 (current time) --> executing until 181093
# Time 1111 <= 181093 (current time) --> executing until 182204
# Time 1111 <= 182204 (current time) --> executing until 183315
# Time 1111 <= 183315 (current time) --> executing until 184426
# Time 1111 <= 184426 (current time) --> executing until 185537
# Time 1111 <= 185537 (current time) --> executing until 186648
# Time 1111 <= 186648 (current time) --> executing until 187759
# Time 1111 <= 187759 (current time) --> executing until 188870
# Time 1111 <= 188870 (current time) --> executing until 189981
# Time 1111 <= 189981 (current time) --> executing until 191092
# Time 1111 <= 191092 (current time) --> executing until 192203
# Time 1111 <= 192203 (current time) --> executing until 193314
# Time 1111 <= 193314 (current time) --> executing until 194425
# Time 1111 <= 194425 (current time) --> executing until 195536
# Time 1111 <= 195536 (current time) --> executing until 196647
# Time 1111 <= 196647 (current time) --> executing until 197758
# Time 1111 <= 197758 (current time) --> executing until 198869
# Time 1111 <= 198869 (current time) --> executing until 199980
# Time 1111 <= 199980 (current time) --> executing until 201091
# Time 1111 <= 201091 (current time) --> executing until 202202
# Time 1111 <= 202202 (current time) --> executing until 203313
# Time 1111 <= 203313 (current time) --> executing until 204424
# Time 1111 <= 204424 (current time) --> executing until 205535
# Time 1111 <= 205535 (current time) --> executing until 206646
# Time 1111 <= 206646 (current time) --> executing until 207757
# Time 1111 <= 207757 (current time) --> executing until 208868
# Time 1111 <= 208868 (current time) --> executing until 209979
# Time 1111 <= 209979 (current time) --> executing until 211090
# Time 1111 <= 211090 (current time) --> executing until 212201
# Time 1111 <= 212201 (current time) --> executing until 213312
# Time 1111 <= 213312 (current time) --> executing until 214423
# Time 1111 <= 214423 (current time) --> executing until 215534
# Time 1111 <= 215534 (current time) --> executing until 216645
# Time 1111 <= 216645 (current time) --> executing until 217756
# Time 1111 <= 217756 (current time) --> executing until 218867
# Time 1111 <= 218867 (current time) --> executing until 219978
# Time 1111 <= 219978 (current time) --> executing until 221089
# Time 1111 <= 221089 (current time) --> executing until 222200
# Time 1111 <= 222200 (current time) --> executing until 223311
# Time 1111 <= 223311 (current time) --> executing until 224422
# Time 1111 <= 224422 (current time) --> executing until 225533
# Time 1111 <= 225533 (current time) --> executing until 226644
# Time 1111 <= 226644 (current time) --> executing until 227755
# Time 1111 <= 227755 (current time) --> executing until 228866
# Time 1111 <= 228866 (current time) --> executing until 229977
# Time 1111 <= 229977 (current time) --> executing until 231088
# Time 1111 <= 231088 (current time) --> executing until 232199
# Time 1111 <= 232199 (current time) --> executing until 233310
# Time 1111 <= 233310 (current time) --> executing until 234421
# Time 1111 <= 234421 (current time) --> executing until 235532
# Time 1111 <= 235532 (current time) --> executing until 236643
# Time 1111 <= 236643 (current time) --> executing until 237754
# Time 1111 <= 237754 (current time) --> executing until 238865
# Time 1111 <= 238865 (current time) --> executing until 239976
# Time 1111 <= 239976 (current time) --> executing until 241087
# Time 1111 <= 241087 (current time) --> executing until 242198
# Time 1111 <= 242198 (current time) --> executing until 243309
# Time 1111 <= 243309 (current time) --> executing until 244420
# Time 1111 <= 244420 (current time) --> executing until 245531
# Time 1111 <= 245531 (current time) --> executing until 246642
# Time 1111 <= 246642 (current time) --> executing until 247753
# Time 1111 <= 247753 (current time) --> executing until 248864
# Time 1111 <= 248864 (current time) --> executing until 249975
# Time 1111 <= 249975 (current time) --> executing until 251086
# Time 1111 <= 251086 (current time) --> executing until 252197
# Time 1111 <= 252197 (current time) --> executing until 253308
# Time 1111 <= 253308 (current time) --> executing until 254419
# Time 1111 <= 254419 (current time) --> executing until 255530
# Time 1111 <= 255530 (current time) --> executing until 256641
# Time 1111 <= 256641 (current time) --> executing until 257752
# Time 1111 <= 257752 (current time) --> executing until 258863
# Time 1111 <= 258863 (current time) --> executing until 259974
# Time 1111 <= 259974 (current time) --> executing until 261085
# Time 1111 <= 261085 (current time) --> executing until 262196
# Time 1111 <= 262196 (current time) --> executing until 263307
# Time 1111 <= 263307 (current time) --> executing until 264418
# Time 1111 <= 264418 (current time) --> executing until 265529
# Time 1111 <= 265529 (current time) --> executing until 266640
# Time 1111 <= 266640 (current time) --> executing until 267751
# Time 1111 <= 267751 (current time) --> executing until 268862
# Time 1111 <= 268862 (current time) --> executing until 269973
# Time 1111 <= 269973 (current time) --> executing until 271084
# Time 1111 <= 271084 (current time) --> executing until 272195
# Time 1111 <= 272195 (current time) --> executing until 273306
# Time 1111 <= 273306 (current time) --> executing until 274417
# Time 1111 <= 274417 (current time) --> executing until 275528
# Time 1111 <= 275528 (current time) --> executing until 276639
# Time 1111 <= 276639 (current time) --> executing until 277750
# Time 1111 <= 277750 (current time) --> executing until 278861
# Time 1111 <= 278861 (current time) --> executing until 279972
# Time 1111 <= 279972 (current time) --> executing until 281083
# Time 1111 <= 281083 (current time) --> executing until 282194
# Time 1111 <= 282194 (current time) --> executing until 283305
# Time 1111 <= 283305 (current time) --> executing until 284416
# Time 1111 <= 284416 (current time) --> executing until 285527
# Time 1111 <= 285527 (current time) --> executing until 286638
# Time 1111 <= 286638 (current time) --> executing until 287749
# Time 1111 <= 287749 (current time) --> executing until 288860
# Time 1111 <= 288860 (current time) --> executing until 289971
# Time 1111 <= 289971 (current time) --> executing until 291082
# Time 1111 <= 291082 (current time) --> executing until 292193
# Time 1111 <= 292193 (current time) --> executing until 293304
# Time 1111 <= 293304 (current time) --> executing until 294415
# Time 1111 <= 294415 (current time) --> executing until 295526
# Time 1111 <= 295526 (current time) --> executing until 296637
# Time 1111 <= 296637 (current time) --> executing until 297748
# Time 1111 <= 297748 (current time) --> executing until 298859
# Time 1111 <= 298859 (current time) --> executing until 299970
# Time 1111 <= 299970 (current time) --> executing until 301081
# Time 1111 <= 301081 (current time) --> executing until 302192
# Time 1111 <= 302192 (current time) --> executing until 303303
# Time 1111 <= 303303 (current time) --> executing until 304414
# Time 1111 <= 304414 (current time) --> executing until 305525
# Time 1111 <= 305525 (current time) --> executing until 306636
# Time 1111 <= 306636 (current time) --> executing until 307747
# Time 1111 <= 307747 (current time) --> executing until 308858
# Time 1111 <= 308858 (current time) --> executing until 309969
# Time 1111 <= 309969 (current time) --> executing until 311080
# Time 1111 <= 311080 (current time) --> executing until 312191
# Time 1111 <= 312191 (current time) --> executing until 313302
# Time 1111 <= 313302 (current time) --> executing until 314413
# Time 1111 <= 314413 (current time) --> executing until 315524
# Time 1111 <= 315524 (current time) --> executing until 316635
# Time 1111 <= 316635 (current time) --> executing until 317746
# Time 1111 <= 317746 (current time) --> executing until 318857
# Time 1111 <= 318857 (current time) --> executing until 319968
# Time 1111 <= 319968 (current time) --> executing until 321079
# Time 1111 <= 321079 (current time) --> executing until 322190
# Time 1111 <= 322190 (current time) --> executing until 323301
# Time 1111 <= 323301 (current time) --> executing until 324412
# Time 1111 <= 324412 (current time) --> executing until 325523
# Time 1111 <= 325523 (current time) --> executing until 326634
# Time 1111 <= 326634 (current time) --> executing until 327745
# Time 1111 <= 327745 (current time) --> executing until 328856
# Time 1111 <= 328856 (current time) --> executing until 329967
# Time 1111 <= 329967 (current time) --> executing until 331078
# Time 1111 <= 331078 (current time) --> executing until 332189
# Time 1111 <= 332189 (current time) --> executing until 333300
# Time 1111 <= 333300 (current time) --> executing until 334411
# Time 1111 <= 334411 (current time) --> executing until 335522
# Time 1111 <= 335522 (current time) --> executing until 336633
# Time 1111 <= 336633 (current time) --> executing until 337744
# Time 1111 <= 337744 (current time) --> executing until 338855
# Time 1111 <= 338855 (current time) --> executing until 339966
# Time 1111 <= 339966 (current time) --> executing until 341077
# Time 1111 <= 341077 (current time) --> executing until 342188
# Time 1111 <= 342188 (current time) --> executing until 343299
# Time 1111 <= 343299 (current time) --> executing until 344410
# Time 1111 <= 344410 (current time) --> executing until 345521
# Time 1111 <= 345521 (current time) --> executing until 346632
# Time 1111 <= 346632 (current time) --> executing until 347743
# Time 1111 <= 347743 (current time) --> executing until 348854
# Time 1111 <= 348854 (current time) --> executing until 349965
# Time 1111 <= 349965 (current time) --> executing until 351076
# Time 1111 <= 351076 (current time) --> executing until 352187
# Time 1111 <= 352187 (current time) --> executing until 353298
# Time 1111 <= 353298 (current time) --> executing until 354409
# Time 1111 <= 354409 (current time) --> executing until 355520
# Time 1111 <= 355520 (current time) --> executing until 356631
# Time 1111 <= 356631 (current time) --> executing until 357742
# Time 1111 <= 357742 (current time) --> executing until 358853
# Time 1111 <= 358853 (current time) --> executing until 359964
# Time 1111 <= 359964 (current time) --> executing until 361075
# Time 1111 <= 361075 (current time) --> executing until 362186
# Time 1111 <= 362186 (current time) --> executing until 363297
# Time 1111 <= 363297 (current time) --> executing until 364408
# Time 1111 <= 364408 (current time) --> executing until 365519
# Time 1111 <= 365519 (current time) --> executing until 366630
# Time 1111 <= 366630 (current time) --> executing until 367741
# Time 1111 <= 367741 (current time) --> executing until 368852
# Time 1111 <= 368852 (current time) --> executing until 369963
# Time 1111 <= 369963 (current time) --> executing until 371074
# Time 1111 <= 371074 (current time) --> executing until 372185
# Time 1111 <= 372185 (current time) --> executing until 373296
# Time 1111 <= 373296 (current time) --> executing until 374407
# Time 1111 <= 374407 (current time) --> executing until 375518
# Time 1111 <= 375518 (current time) --> executing until 376629
# Time 1111 <= 376629 (current time) --> executing until 377740
# Time 1111 <= 377740 (current time) --> executing until 378851
# Time 1111 <= 378851 (current time) --> executing until 379962
# Time 1111 <= 379962 (current time) --> executing until 381073
# Time 1111 <= 381073 (current time) --> executing until 382184
# Time 1111 <= 382184 (current time) --> executing until 383295
# Time 1111 <= 383295 (current time) --> executing until 384406
# Time 1111 <= 384406 (current time) --> executing until 385517
# Time 1111 <= 385517 (current time) --> executing until 386628
# Time 1111 <= 386628 (current time) --> executing until 387739
# Time 1111 <= 387739 (current time) --> executing until 388850
# Time 1111 <= 388850 (current time) --> executing until 389961
# Time 1111 <= 389961 (current time) --> executing until 391072
# Time 1111 <= 391072 (current time) --> executing until 392183
# Time 1111 <= 392183 (current time) --> executing until 393294
# Time 1111 <= 393294 (current time) --> executing until 394405
# Time 1111 <= 394405 (current time) --> executing until 395516
# Time 1111 <= 395516 (current time) --> executing until 396627
# Time 1111 <= 396627 (current time) --> executing until 397738
# Time 1111 <= 397738 (current time) --> executing until 398849
# Time 1111 <= 398849 (current time) --> executing until 399960
# Time 1111 <= 399960 (current time) --> executing until 401071
# Time 1111 <= 401071 (current time) --> executing until 402182
# Time 1111 <= 402182 (current time) --> executing until 403293
# Time 1111 <= 403293 (current time) --> executing until 404404
# Time 1111 <= 404404 (current time) --> executing until 405515
# Time 1111 <= 405515 (current time) --> executing until 406626
# Time 1111 <= 406626 (current time) --> executing until 407737
# Time 1111 <= 407737 (current time) --> executing until 408848
# Time 1111 <= 408848 (current time) --> executing until 409959
# Time 1111 <= 409959 (current time) --> executing until 411070
# Time 1111 <= 411070 (current time) --> executing until 412181
# Time 1111 <= 412181 (current time) --> executing until 413292
# Time 1111 <= 413292 (current time) --> executing until 414403
# Time 1111 <= 414403 (current time) --> executing until 415514
# Time 1111 <= 415514 (current time) --> executing until 416625
# Time 1111 <= 416625 (current time) --> executing until 417736
# Time 1111 <= 417736 (current time) --> executing until 418847
# Time 1111 <= 418847 (current time) --> executing until 419958
# Time 1111 <= 419958 (current time) --> executing until 421069
# Time 1111 <= 421069 (current time) --> executing until 422180
# Time 1111 <= 422180 (current time) --> executing until 423291
# Time 1111 <= 423291 (current time) --> executing until 424402
# Time 1111 <= 424402 (current time) --> executing until 425513
# Time 1111 <= 425513 (current time) --> executing until 426624
# Time 1111 <= 426624 (current time) --> executing until 427735
# Time 1111 <= 427735 (current time) --> executing until 428846
# Time 1111 <= 428846 (current time) --> executing until 429957
# Time 1111 <= 429957 (current time) --> executing until 431068
# Time 1111 <= 431068 (current time) --> executing until 432179
# Time 1111 <= 432179 (current time) --> executing until 433290
# Time 1111 <= 433290 (current time) --> executing until 434401
# Time 1111 <= 434401 (current time) --> executing until 435512
# Time 1111 <= 435512 (current time) --> executing until 436623
# Time 1111 <= 436623 (current time) --> executing until 437734
# Time 1111 <= 437734 (current time) --> executing until 438845
# Time 1111 <= 438845 (current time) --> executing until 439956
# Time 1111 <= 439956 (current time) --> executing until 441067
# Time 1111 <= 441067 (current time) --> executing until 442178
# Time 1111 <= 442178 (current time) --> executing until 443289
# Time 1111 <= 443289 (current time) --> executing until 444400
# Time 1111 <= 444400 (current time) --> executing until 445511
# Time 1111 <= 445511 (current time) --> executing until 446622
# Time 1111 <= 446622 (current time) --> executing until 447733
# Time 1111 <= 447733 (current time) --> executing until 448844
# Time 1111 <= 448844 (current time) --> executing until 449955
# Time 1111 <= 449955 (current time) --> executing until 451066
# Time 1111 <= 451066 (current time) --> executing until 452177
# Time 1111 <= 452177 (current time) --> executing until 453288
# Time 1111 <= 453288 (current time) --> executing until 454399
# Time 1111 <= 454399 (current time) --> executing until 455510
# Time 1111 <= 455510 (current time) --> executing until 456621
# Time 1111 <= 456621 (current time) --> executing until 457732
# Time 1111 <= 457732 (current time) --> executing until 458843
# Time 1111 <= 458843 (current time) --> executing until 459954
# Time 1111 <= 459954 (current time) --> executing until 461065
# Time 1111 <= 461065 (current time) --> executing until 462176
# Time 1111 <= 462176 (current time) --> executing until 463287
# Time 1111 <= 463287 (current time) --> executing until 464398
# Time 1111 <= 464398 (current time) --> executing until 465509
# Time 1111 <= 465509 (current time) --> executing until 466620
# Time 1111 <= 466620 (current time) --> executing until 467731
# Time 1111 <= 467731 (current time) --> executing until 468842
# Time 1111 <= 468842 (current time) --> executing until 469953
# Time 1111 <= 469953 (current time) --> executing until 471064
# Time 1111 <= 471064 (current time) --> executing until 472175
# Time 1111 <= 472175 (current time) --> executing until 473286
# Time 1111 <= 473286 (current time) --> executing until 474397
# Time 1111 <= 474397 (current time) --> executing until 475508
# Time 1111 <= 475508 (current time) --> executing until 476619
# Time 1111 <= 476619 (current time) --> executing until 477730
# Time 1111 <= 477730 (current time) --> executing until 478841
# Time 1111 <= 478841 (current time) --> executing until 479952
# Time 1111 <= 479952 (current time) --> executing until 481063
# Time 1111 <= 481063 (current time) --> executing until 482174
# Time 1111 <= 482174 (current time) --> executing until 483285
# Time 1111 <= 483285 (current time) --> executing until 484396
# Time 1111 <= 484396 (current time) --> executing until 485507
# Time 1111 <= 485507 (current time) --> executing until 486618
# Time 1111 <= 486618 (current time) --> executing until 487729
# Time 1111 <= 487729 (current time) --> executing until 488840
# Time 1111 <= 488840 (current time) --> executing until 489951
# Time 1111 <= 489951 (current time) --> executing until 491062
# Time 1111 <= 491062 (current time) --> executing until 492173
# Time 1111 <= 492173 (current time) --> executing until 493284
# Time 1111 <= 493284 (current time) --> executing until 494395
# Time 1111 <= 494395 (current time) --> executing until 495506
# Time 1111 <= 495506 (current time) --> executing until 496617
# Time 1111 <= 496617 (current time) --> executing until 497728
# Time 1111 <= 497728 (current time) --> executing until 498839
# Time 1111 <= 498839 (current time) --> executing until 499950
# Time 1111 <= 499950 (current time) --> executing until 501061
# Time 1111 <= 501061 (current time) --> executing until 502172
# Time 1111 <= 502172 (current time) --> executing until 503283
# Time 1111 <= 503283 (current time) --> executing until 504394
# Time 1111 <= 504394 (current time) --> executing until 505505
# Time 1111 <= 505505 (current time) --> executing until 506616
# Time 1111 <= 506616 (current time) --> executing until 507727
# Time 1111 <= 507727 (current time) --> executing until 508838
# Time 1111 <= 508838 (current time) --> executing until 509949
# Time 1111 <= 509949 (current time) --> executing until 511060
# Time 1111 <= 511060 (current time) --> executing until 512171
# Time 1111 <= 512171 (current time) --> executing until 513282
# Time 1111 <= 513282 (current time) --> executing until 514393
# Time 1111 <= 514393 (current time) --> executing until 515504
# Time 1111 <= 515504 (current time) --> executing until 516615
# Time 1111 <= 516615 (current time) --> executing until 517726
# Time 1111 <= 517726 (current time) --> executing until 518837
# Time 1111 <= 518837 (current time) --> executing until 519948
# Time 1111 <= 519948 (current time) --> executing until 521059
# Time 1111 <= 521059 (current time) --> executing until 522170
# Time 1111 <= 522170 (current time) --> executing until 523281
# Time 1111 <= 523281 (current time) --> executing until 524392
# Time 1111 <= 524392 (current time) --> executing until 525503
# Time 1111 <= 525503 (current time) --> executing until 526614
# Time 1111 <= 526614 (current time) --> executing until 527725
# Time 1111 <= 527725 (current time) --> executing until 528836
# Time 1111 <= 528836 (current time) --> executing until 529947
# Time 1111 <= 529947 (current time) --> executing until 531058
# Time 1111 <= 531058 (current time) --> executing until 532169
# Time 1111 <= 532169 (current time) --> executing until 533280
# Time 1111 <= 533280 (current time) --> executing until 534391
# Time 1111 <= 534391 (current time) --> executing until 535502
# Time 1111 <= 535502 (current time) --> executing until 536613
# Time 1111 <= 536613 (current time) --> executing until 537724
# Time 1111 <= 537724 (current time) --> executing until 538835
# Time 1111 <= 538835 (current time) --> executing until 539946
# Time 1111 <= 539946 (current time) --> executing until 541057
# Time 1111 <= 541057 (current time) --> executing until 542168
# Time 1111 <= 542168 (current time) --> executing until 543279
# Time 1111 <= 543279 (current time) --> executing until 544390
# Time 1111 <= 544390 (current time) --> executing until 545501
# Time 1111 <= 545501 (current time) --> executing until 546612
# Time 1111 <= 546612 (current time) --> executing until 547723
# Time 1111 <= 547723 (current time) --> executing until 548834
# Time 1111 <= 548834 (current time) --> executing until 549945
# Time 1111 <= 549945 (current time) --> executing until 551056
# Time 1111 <= 551056 (current time) --> executing until 552167
# Time 1111 <= 552167 (current time) --> executing until 553278
# Time 1111 <= 553278 (current time) --> executing until 554389
# Time 1111 <= 554389 (current time) --> executing until 555500
# Time 1111 <= 555500 (current time) --> executing until 556611
# Time 1111 <= 556611 (current time) --> executing until 557722
# Time 1111 <= 557722 (current time) --> executing until 558833
# Time 1111 <= 558833 (current time) --> executing until 559944
# Time 1111 <= 559944 (current time) --> executing until 561055
# Time 1111 <= 561055 (current time) --> executing until 562166
# Time 1111 <= 562166 (current time) --> executing until 563277
# Time 1111 <= 563277 (current time) --> executing until 564388
# Time 1111 <= 564388 (current time) --> executing until 565499
# Time 1111 <= 565499 (current time) --> executing until 566610
# Time 1111 <= 566610 (current time) --> executing until 567721
# Time 1111 <= 567721 (current time) --> executing until 568832
# Time 1111 <= 568832 (current time) --> executing until 569943
# Time 1111 <= 569943 (current time) --> executing until 571054
# Time 1111 <= 571054 (current time) --> executing until 572165
# Time 1111 <= 572165 (current time) --> executing until 573276
# Time 1111 <= 573276 (current time) --> executing until 574387
# Time 1111 <= 574387 (current time) --> executing until 575498
# Time 1111 <= 575498 (current time) --> executing until 576609
# Time 1111 <= 576609 (current time) --> executing until 577720
# Time 1111 <= 577720 (current time) --> executing until 578831
# Time 1111 <= 578831 (current time) --> executing until 579942
# Time 1111 <= 579942 (current time) --> executing until 581053
# Time 1111 <= 581053 (current time) --> executing until 582164
# Time 1111 <= 582164 (current time) --> executing until 583275
# Time 1111 <= 583275 (current time) --> executing until 584386
# Time 1111 <= 584386 (current time) --> executing until 585497
# Time 1111 <= 585497 (current time) --> executing until 586608
# Time 1111 <= 586608 (current time) --> executing until 587719
# Time 1111 <= 587719 (current time) --> executing until 588830
# Time 1111 <= 588830 (current time) --> executing until 589941
# Time 1111 <= 589941 (current time) --> executing until 591052
# Time 1111 <= 591052 (current time) --> executing until 592163
# Time 1111 <= 592163 (current time) --> executing until 593274
# Time 1111 <= 593274 (current time) --> executing until 594385
# Time 1111 <= 594385 (current time) --> executing until 595496
# Time 1111 <= 595496 (current time) --> executing until 596607
# Time 1111 <= 596607 (current time) --> executing until 597718
# Time 1111 <= 597718 (current time) --> executing until 598829
# Time 1111 <= 598829 (current time) --> executing until 599940
# Time 1111 <= 599940 (current time) --> executing until 601051
# Time 1111 <= 601051 (current time) --> executing until 602162
# Time 1111 <= 602162 (current time) --> executing until 603273
# Time 1111 <= 603273 (current time) --> executing until 604384
# Time 1111 <= 604384 (current time) --> executing until 605495
# Time 1111 <= 605495 (current time) --> executing until 606606
# Time 1111 <= 606606 (current time) --> executing until 607717
# Time 1111 <= 607717 (current time) --> executing until 608828
# Time 1111 <= 608828 (current time) --> executing until 609939
# Time 1111 <= 609939 (current time) --> executing until 611050
# Time 1111 <= 611050 (current time) --> executing until 612161
# Time 1111 <= 612161 (current time) --> executing until 613272
# Time 1111 <= 613272 (current time) --> executing until 614383
# Time 1111 <= 614383 (current time) --> executing until 615494
# Time 1111 <= 615494 (current time) --> executing until 616605
# Time 1111 <= 616605 (current time) --> executing until 617716
# Time 1111 <= 617716 (current time) --> executing until 618827
# Time 1111 <= 618827 (current time) --> executing until 619938
# Time 1111 <= 619938 (current time) --> executing until 621049
# Time 1111 <= 621049 (current time) --> executing until 622160
# Time 1111 <= 622160 (current time) --> executing until 623271
# Time 1111 <= 623271 (current time) --> executing until 624382
# Time 1111 <= 624382 (current time) --> executing until 625493
# Time 1111 <= 625493 (current time) --> executing until 626604
# Time 1111 <= 626604 (current time) --> executing until 627715
# Time 1111 <= 627715 (current time) --> executing until 628826
# Time 1111 <= 628826 (current time) --> executing until 629937
# Time 1111 <= 629937 (current time) --> executing until 631048
# Time 1111 <= 631048 (current time) --> executing until 632159
# Time 1111 <= 632159 (current time) --> executing until 633270
# Time 1111 <= 633270 (current time) --> executing until 634381
# Time 1111 <= 634381 (current time) --> executing until 635492
# Time 1111 <= 635492 (current time) --> executing until 636603
# Time 1111 <= 636603 (current time) --> executing until 637714
# Time 1111 <= 637714 (current time) --> executing until 638825
# Time 1111 <= 638825 (current time) --> executing until 639936
# Time 1111 <= 639936 (current time) --> executing until 641047
# Time 1111 <= 641047 (current time) --> executing until 642158
# Time 1111 <= 642158 (current time) --> executing until 643269
# Time 1111 <= 643269 (current time) --> executing until 644380
# Time 1111 <= 644380 (current time) --> executing until 645491
# Time 1111 <= 645491 (current time) --> executing until 646602
# Time 1111 <= 646602 (current time) --> executing until 647713
# Time 1111 <= 647713 (current time) --> executing until 648824
# Time 1111 <= 648824 (current time) --> executing until 649935
# Time 1111 <= 649935 (current time) --> executing until 651046
# Time 1111 <= 651046 (current time) --> executing until 652157
# Time 1111 <= 652157 (current time) --> executing until 653268
# Time 1111 <= 653268 (current time) --> executing until 654379
# Time 1111 <= 654379 (current time) --> executing until 655490
# Time 1111 <= 655490 (current time) --> executing until 656601
# Time 1111 <= 656601 (current time) --> executing until 657712
# Time 1111 <= 657712 (current time) --> executing until 658823
# Time 1111 <= 658823 (current time) --> executing until 659934
# Time 1111 <= 659934 (current time) --> executing until 661045
# Time 1111 <= 661045 (current time) --> executing until 662156
# Time 1111 <= 662156 (current time) --> executing until 663267
# Time 1111 <= 663267 (current time) --> executing until 664378
# Time 1111 <= 664378 (current time) --> executing until 665489
# Time 1111 <= 665489 (current time) --> executing until 666600
# Time 1111 <= 666600 (current time) --> executing until 667711
# Time 1111 <= 667711 (current time) --> executing until 668822
# Time 1111 <= 668822 (current time) --> executing until 669933
# Time 1111 <= 669933 (current time) --> executing until 671044
# Time 1111 <= 671044 (current time) --> executing until 672155
# Time 1111 <= 672155 (current time) --> executing until 673266
# Time 1111 <= 673266 (current time) --> executing until 674377
# Time 1111 <= 674377 (current time) --> executing until 675488
# Time 1111 <= 675488 (current time) --> executing until 676599
# Time 1111 <= 676599 (current time) --> executing until 677710
# Time 1111 <= 677710 (current time) --> executing until 678821
# Time 1111 <= 678821 (current time) --> executing until 679932
# Time 1111 <= 679932 (current time) --> executing until 681043
# Time 1111 <= 681043 (current time) --> executing until 682154
# Time 1111 <= 682154 (current time) --> executing until 683265
# Time 1111 <= 683265 (current time) --> executing until 684376
# Time 1111 <= 684376 (current time) --> executing until 685487
# Time 1111 <= 685487 (current time) --> executing until 686598
# Time 1111 <= 686598 (current time) --> executing until 687709
# Time 1111 <= 687709 (current time) --> executing until 688820
# Best solution found: [2 9 6 4 0 3 1 7 8 5]
# Function value: [358.11128942]
